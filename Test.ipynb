# %%
import pandas as pd

df = pd.read_csv("./dataset/course.csv")

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3678 entries, 0 to 3677
# Data columns (total 12 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   course_id            3678 non-null   int64
#  1   course_title         3678 non-null   object
#  2   url                  3678 non-null   object
#  3   is_paid              3678 non-null   bool
#  4   price                3678 non-null   int64
#  5   num_subscribers      3678 non-null   int64
#  6   num_reviews          3678 non-null   int64
#  7   num_lectures         3678 non-null   int64
#  8   level                3678 non-null   object
#  9   content_duration     3678 non-null   float64
#  10  published_timestamp  3678 non-null   object
#  11  subject              3678 non-null   object
# dtypes: bool(1), float64(1), int64(5), object(5)
# memory usage: 319.8+ KB

# %%
df.head()
# Out:
#    course_id                                       course_title  \
# 0    1070968                 Ultimate Investment Banking Course
# 1    1113822  Complete GST Course & Certification - Grow You...
# 2    1006314  Financial Modeling for Business Analysts and C...
# 3    1210588  Beginner to Pro - Financial Analysis in Excel ...
# 4    1011058       How To Maximize Your Profits Trading Options
#
#                                                  url  is_paid  price  \
# 0  https://www.udemy.com/ultimate-investment-bank...     True    200
# 1      https://www.udemy.com/goods-and-services-tax/     True     75
# 2  https://www.udemy.com/financial-modeling-for-b...     True     45
# 3  https://www.udemy.com/complete-excel-finance-c...     True     95
# 4  https://www.udemy.com/how-to-maximize-your-pro...     True    200
#
#    num_subscribers  num_reviews  num_lectures               level  \
# 0             2147           23            51          All Levels
# ...

# %%
df[df.duplicated()]
# Out:
# Empty DataFrame
# Columns: [course_id, course_title, url, is_paid, price, num_subscribers, num_reviews, num_lectures, level, content_duration, published_timestamp, subject]
# Index: []

# %%
df.drop_duplicates(inplace = True)

# %%
df["course_id"].nunique()
# Out:
# 3672

# %%
df["published_timestamp"] = pd.to_datetime(df["published_timestamp"],format = "mixed")
df.dtypes
# Out:
# course_id                            int64
# course_title                        object
# url                                 object
# is_paid                               bool
# price                                int64
# num_subscribers                      int64
# num_reviews                          int64
# num_lectures                         int64
# level                               object
# content_duration                   float64
# published_timestamp    datetime64[ns, UTC]
# subject                             object
# dtype: object

# %%
df["content_duration"] = df["content_duration"].astype("timedelta64[ns]")
df.dtypes
# Out:
# course_id                            int64
# course_title                        object
# url                                 object
# is_paid                               bool
# price                                int64
# num_subscribers                      int64
# num_reviews                          int64
# num_lectures                         int64
# level                               object
# content_duration           timedelta64[ns]
# published_timestamp    datetime64[ns, UTC]
# subject                             object
# dtype: object

# %%
df.shape
# Out:
# (3672, 12)

# %%
df["content_duration"].min()
# Out:
# Timedelta('0 days 00:00:00')

# %%
df.loc[(df["content_duration"]<="0 days 00:00:00"),["course_id","course_title","published_timestamp"]]
# Out:
#       course_id                                       course_title  \
# 19        58977                     Financial Statements Made Easy
# 91      1217064        How To Invest With Tiny Capital In Stocks ?
# 95      1148774                    Options Trading 101: The Basics
# 116     1191504                    How to create a routine Trading
# 117      585752  Forex Trading Secrets |MT4 Robot (EA) inside, ...
# ...         ...                                                ...
# 3649    1018530                Cakephp:Creating a CRUD application
# 3655     833182  JQuery DOM and Ajax Concept Explained for Begi...
# 3666     968292                        XPATH :basics for beginners
# 3667     523216  The Fastest Way to Create a Website Using Godaddy
# 3668     270976                             A how to guide in HTML
#
#            published_timestamp
# 19   2013-06-09 00:21:26+00:00
# 91   2017-05-23 16:07:09+00:00
# 95   2017-03-23 22:19:57+00:00
# 116  2017-05-01 18:50:43+00:00
# ...

# %%
df.loc[(df["price"]>0) & (df["is_paid"] == False),["course_id"]]
# Out:
# Empty DataFrame
# Columns: [course_id]
# Index: []

# %%
df.loc[(df["price"].max() == df["price"])]
# Out:
#       course_id                                       course_title  \
# 0       1070968                 Ultimate Investment Banking Course
# 4       1011058       How To Maximize Your Profits Trading Options
# 9       1167710  The Only Investment Strategy You Need For Your...
# 10       592338  Forex Trading Secrets of the Pros With Amazon'...
# 11       975046                    Trading Options With Money Flow
# ...         ...                                                ...
# 3592     976854  Spring 4 Mastercourse: Covers Annotation & XML...
# 3620    1227578           Learning Path: The Road to Elasticsearch
# 3642     709324  Learn Web Development by Creating a Social Net...
# 3652     919354  Learn Bootstrap 4 The Most Popular HTML5 CSS3 ...
# 3654     949134  The Extreme Web Development Course - For Begin...
#
#                                                     url  is_paid  price  \
# 0     https://www.udemy.com/ultimate-investment-bank...     True    200
# ...

# %%
df.groupby("level")["price"].sum()
# Out:
# level
# All Levels            140700
# Beginner Level         70675
# Expert Level            5285
# Intermediate Level     26070
# Name: price, dtype: int64
