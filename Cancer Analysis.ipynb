# %%
pip install openpyxl
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.0.1 -> 25.1.1
# [notice] To update, run: C:\Users\USER\AppData\Local\Programs\Python\Python310\python.exe -m pip install --upgrade pip

# %% [markdown]
# ## Objective
#
# possibilities of having cancer based on their lifestyles

# %% [markdown]
# Due to the lifestyle they choose
#     Alcohol use,,Obesity,Smoking
# Due to a good Lifestyle
#     Balanced Diet
# Due to living condition
#     Air pollution,Dust Allergy,Occupational hazard,passive smoking
# Due to Heriditary
#     Genetic Risk
# Symptoms of a person have Cancer
#     Chronic Lung Disease,Chest Pain,Coughing of blood,Fatigue,Weight Loss,Shortness of Breath,Wheezing,Swallowing Difficulty,Clubbing of finger Nails,frequent cold,Dry Cough
#
#     How much these symptoms are related to their cancer level
#
#     why the people choose to be higly chose bad lifestyle by analyzing the living condition we can figure that out
#
#     what are the factors that made the prople who had a very healthy diest subjected to cancer
#
#     at last how snoring affects the cancer experimental

# %%
import pandas as pd
import openpyxl

# %%
df = pd.read_excel("./dataset/cancer.xlsx")
df.head()
reasons = ["Patient Id","Age","Gender","Air Pollution","Alcohol use","OccuPational Hazards","Genetic Risk","Balanced Diet","Obesity","Smoking","Passive Smoker","Level"]
symptoms = ["Dust Allergy","Chronic Lung Disease","Chest Pain","Coughing of Blood","Fatigue","Weight Loss","Shortness of breath","Wheezing","Swallowing Difficulty","Clubbing of Finger Nails","Frequent Cold","Dry Cough"]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 25 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Patient Id                1000 non-null   object
#  1   Age                       1000 non-null   int64
#  2   Gender                    1000 non-null   int64
#  3   Air Pollution             1000 non-null   int64
#  4   Alcohol use               1000 non-null   int64
#  5   Dust Allergy              1000 non-null   int64
#  6   OccuPational Hazards      1000 non-null   int64
#  7   Genetic Risk              1000 non-null   int64
#  8   chronic Lung Disease      1000 non-null   int64
#  9   Balanced Diet             1000 non-null   int64
#  10  Obesity                   1000 non-null   int64
#  11  Smoking                   1000 non-null   int64
#  12  Passive Smoker            1000 non-null   int64
#  13  Chest Pain                1000 non-null   int64
# ...

# %%
print(df.describe())
# Out:
#                Age       Gender  Air Pollution  Alcohol use  Dust Allergy  \
# count  1000.000000  1000.000000      1000.0000  1000.000000   1000.000000
# mean     37.174000     1.402000         3.8400     4.563000      5.165000
# std      12.005493     0.490547         2.0304     2.620477      1.980833
# min      14.000000     1.000000         1.0000     1.000000      1.000000
# 25%      27.750000     1.000000         2.0000     2.000000      4.000000
# 50%      36.000000     1.000000         3.0000     5.000000      6.000000
# 75%      45.000000     2.000000         6.0000     7.000000      7.000000
# max      73.000000     2.000000         8.0000     8.000000      8.000000
#
#        OccuPational Hazards  Genetic Risk  chronic Lung Disease  \
# count           1000.000000   1000.000000           1000.000000
# mean               4.840000      4.580000              4.380000
# std                2.107805      2.126999              1.848518
# ...

# %%
df.duplicated().sum()
#0 duplicate value
# Out:
# np.int64(0)

# %%
bad_lifestyle = df.loc[(df["Smoking"]>5) & (df["Alcohol use"]>5) & (df["Air Pollution"]<5) & (df["OccuPational Hazards"] <5) & (df["Balanced Diet"]<5) & (df["Passive Smoker"]<5)]
bad_lifestyle
## according to the data given there are no person who got cancer due to drinking and smoking only
# Out:
# Empty DataFrame
# Columns: [Patient Id, Age, Gender, Air Pollution, Alcohol use, Dust Allergy, OccuPational Hazards, Genetic Risk, chronic Lung Disease, Balanced Diet, Obesity, Smoking, Passive Smoker, Chest Pain, Coughing of Blood, Fatigue, Weight Loss, Shortness of Breath, Wheezing, Swallowing Difficulty, Clubbing of Finger Nails, Frequent Cold, Dry Cough, Snoring, Level]
# Index: []
#
# [0 rows x 25 columns]

# %%
uh= df.loc[(df["Smoking"]>5) & (df["Alcohol use"]>5),["Patient Id","Age","Gender","Air Pollution","Alcohol use","OccuPational Hazards","Genetic Risk","Balanced Diet","Obesity","Smoking","Passive Smoker","Level"]]
uh.loc[uh["Age"] < 20]
# Out:
#     Patient Id  Age  Gender  Air Pollution  Alcohol use  OccuPational Hazards  \
# 98        P187   19       1              6            8                     7
# 110       P198   18       2              6            8                     7
# 209       P287   19       1              6            8                     7
# 221       P298   18       2              6            8                     7
# 320       P387   19       1              6            8                     7
# 332       P398   18       2              6            8                     7
# 431       P487   19       1              6            8                     7
# 542       P587   19       1              6            8                     7
# 554       P598   18       2              6            8                     7
# 653       P687   19       1              6            8                     7
# 665       P698   18       2              6            8                     7
# ...

# %% [markdown]
# * Here we get that the young womens who are addicted to both Alchohol, and Smoking had a high level cancer, While according to our data there are no person who got cancer due to the smoking and drinking only
# * and their from this data we can derive that the atmosher they lived maore likey to have a high level cancer ,
# * passive smoker data says that they were surrownded with the people smoking, and may got their habit from their friends, while the fact that they all have high level Genetic risk and obesity even after a great diet

# %%
unhealthy_mid = df.loc[(df["Smoking"]>5) & (df["Alcohol use"]>5),["Patient Id","Age","Gender","Air Pollution","Alcohol use","OccuPational Hazards","Genetic Risk","Balanced Diet","Obesity","Smoking","Passive Smoker","Level"]]
unhealthy_mid.loc[(unhealthy_mid["Age"] < 51) & (unhealthy_mid["Age"] >19) & ( (unhealthy_mid["Air Pollution"] == unhealthy_mid["Air Pollution"].min()) | (unhealthy_mid["Alcohol use"] == unhealthy_mid["Alcohol use"].min()) | (unhealthy_mid["OccuPational Hazards"] == unhealthy_mid["OccuPational Hazards"].min()) | (unhealthy_mid["Genetic Risk"] == unhealthy_mid["Genetic Risk"].min()) | (unhealthy_mid["Balanced Diet"] == unhealthy_mid["Balanced Diet"].min()) | (unhealthy_mid["Obesity"] == df["Obesity"].min()) | (unhealthy_mid["Smoking"] == df["Smoking"].min()) | (unhealthy_mid["Smoking"] == unhealthy_mid["Smoking"].min()))]
# Out:
#     Patient Id  Age  Gender  Air Pollution  Alcohol use  OccuPational Hazards  \
# 3        P1000   37       1              7            7                     7
# 13         P11   34       1              6            7                     7
# 17        P113   34       1              6            7                     7
# 18        P114   36       1              6            7                     7
# 20        P116   24       1              6            8                     7
# ..         ...  ...     ...            ...          ...                   ...
# 912        P92   33       1              6            7                     7
# 918       P925   35       2              2            6                     3
# 989        P99   37       1              7            7                     7
# 993       P993   37       2              7            7                     7
# 994       P994   33       1              6            7                     7
#
# ...

# %%
uh.loc[(unhealthy_mid["Alcohol use"] >7) & (uh["Smoking"] > 7) & (uh["Age"] >= 20) & (uh["Age"] <= 50)].describe()

#nearly 20% of the patients who were heavily addicted to smoking and alcohol got the cancer at highlevel and they lived in a higly unhealthy conditions with a great helthy diet of 7 while the occupational hazard and passive smoing shows they worked on harmul condtions but along with the people smoking which may lead to them beign a addicted to smoking and drinking
# Out:
#     Patient Id  Age  Gender  Air Pollution  Alcohol use  OccuPational Hazards  \
# 4         P101   46       1              6            8                     7
# 20        P116   24       1              6            8                     7
# 46         P14   24       1              6            8                     7
# 93        P182   46       2              6            8                     7
# 100       P189   39       2              6            8                     7
# 103       P191   37       1              8            8                     7
# 114       P200   26       2              8            8                     7
# 131       P216   24       1              6            8                     7
# 204       P282   46       1              6            8                     7
# 211       P289   39       2              6            8                     7
# 214       P291   37       1              8            8                     7
# ...

# %%
uh.loc[ (uh["Age"] >50) & (uh["Age"] <= 80) & (uh["Level"] == "Medium")]
#comparing to others the old people who got medium cancer

#lives in a compritively better enviornement
#low occupatinal hard
#low alcohol usage
#as a result they got medium level cancer , which shows how much important is the enviornement at this same level of evniroement condtion lets check how the rest of the patients does
# Out:
#     Patient Id  Age  Gender  Air Pollution  Alcohol use  OccuPational Hazards  \
# 15        P111   73       1              5            6                     5
# 126       P211   73       1              5            6                     5
# 237       P311   73       1              5            6                     5
# 348       P411   73       1              5            6                     5
# 459       P511   73       1              5            6                     5
# 570       P611   73       1              5            6                     5
# 681       P711   73       1              5            6                     5
# 792       P811   73       1              5            6                     5
# 889         P9   73       1              5            6                     5
# 903       P911   73       1              5            6                     5
#
#      Genetic Risk  Balanced Diet  Obesity  Smoking  Passive Smoker   Level
# ...

# %%
df.loc[(df["Alcohol use"] == 6) & (df["Balanced Diet"] == 6) & (df["Smoking"] == 8)]

#seems like we were unsuccesfull these patients were the only people coming from this kind of section
# Out:
#     Patient Id  Age  Gender  Air Pollution  Alcohol use  Dust Allergy  \
# 15        P111   73       1              5            6             6
# 126       P211   73       1              5            6             6
# 237       P311   73       1              5            6             6
# 348       P411   73       1              5            6             6
# 459       P511   73       1              5            6             6
# 570       P611   73       1              5            6             6
# 681       P711   73       1              5            6             6
# 792       P811   73       1              5            6             6
# 889         P9   73       1              5            6             6
# 903       P911   73       1              5            6             6
#
#      OccuPational Hazards  Genetic Risk  chronic Lung Disease  Balanced Diet  \
# 15                      5             6                     5              6
# ...

# %%
df.loc[(df["Air Pollution"] <= 5) & (df["OccuPational Hazards"] <= 5) & (df["Genetic Risk"] <= 6) & (df["Passive Smoker"] <= 5) & (df["Level"] == "High"),["Patient Id","Age","Gender","Air Pollution","Alcohol use","OccuPational Hazards","Genetic Risk","Balanced Diet","Obesity","Smoking","Passive Smoker","Level"]]

# this means around 5% of the patients got cancer eventhough they have relatively better envirenement and low smokinga nd alcohol consumption
#they all have common obesity as 7
# we can futher ceck them if they were delayed to got the treatement while checking the intensity of the symptoms
# Out:
#     Patient Id  Age  Gender  Air Pollution  Alcohol use  OccuPational Hazards  \
# 2         P100   35       1              4            5                     5
# 5         P102   35       1              4            5                     5
# 21        P117   53       2              4            5                     5
# 57         P15   53       2              4            5                     5
# 92        P181   35       2              4            5                     5
# 99        P188   29       2              4            5                     5
# 109       P197   25       2              4            5                     5
# 116       P202   35       2              4            5                     5
# 132       P217   53       2              4            5                     5
# 203       P281   35       2              4            5                     5
# 210       P288   29       2              4            5                     5
# ...

# %%
df.loc[(df["Level"] == "High"),["Patient Id","Age","Gender","Balanced Diet","Obesity","Smoking","Passive Smoker","Fatigue","Dust Allergy","chronic Lung Disease","Chest Pain","Coughing of Blood","Level",]]

#as we can see the the coughing of blood is a major symptom of cancer, it worsens as the cancer stage grows to dangerous levels , as we can see the patients with low level of blodd coughing had a low level of cancer while as the level incerase 
# the level of cancer incerases since these patient had great enviroemnt conditiin and got the hgih level of canvcer largely due to the late treatement they got,
# Out:
#     Patient Id  Age  Gender  Balanced Diet  Obesity  Smoking  Passive Smoker  \
# 2         P100   35       1              6        7        2               3
# 3        P1000   37       1              7        7        7               7
# 4         P101   46       1              7        7        8               7
# 5         P102   35       1              6        7        2               3
# 10        P107   44       1              7        7        7               8
# ..         ...  ...     ...            ...      ...      ...             ...
# 995       P995   44       1              7        7        7               8
# 996       P996   37       2              7        7        7               8
# 997       P997   25       2              6        7        2               3
# 998       P998   18       2              7        7        8               7
# 999       P999   47       1              6        7        2               3
#
# ...

# %%
ev_mid = df.loc[(df["Air Pollution"] <= 5) & (df["OccuPational Hazards"] <= 5) & (df["Genetic Risk"] <= 6) & (df["Passive Smoker"] <= 5) & (df["Level"] == "Medium"),["Patient Id","Age","Gender","Air Pollution","Alcohol use","OccuPational Hazards","Genetic Risk","Balanced Diet","Obesity","Smoking","Passive Smoker","Level"]]
ev_mid
# here about 20% of the patients who got the cancer at medium level were living in a best environement with very low consmptino of alchohol and smoking , while maintainig ahelay life with less obesity and balanced diet
# Out:
#     Patient Id  Age  Gender  Air Pollution  Alcohol use  OccuPational Hazards  \
# 1          P10   17       1              3            1                     3
# 9         P106   46       1              2            3                     2
# 15        P111   73       1              5            6                     5
# 16        P112   17       1              3            1                     3
# 26        P121   38       2              2            1                     3
# ..         ...  ...     ...            ...          ...                   ...
# 971       P973   36       2              2            1                     3
# 972       P974   31       2              3            2                     2
# 973       P975   38       2              1            2                     4
# 983       P984   26       1              3            2                     2
# 984       P985   37       1              1            2                     4
#
# ...

# %%
ev_low = df.loc[(df["Air Pollution"] <= 5) & (df["OccuPational Hazards"] <= 5) & (df["Genetic Risk"] <= 5) & (df["Passive Smoker"] <= 5) & (df["Level"] == "Low"),["Patient Id","Age","Gender","Air Pollution","Alcohol use","OccuPational Hazards","Genetic Risk","Balanced Diet","Obesity","Smoking","Passive Smoker","Level"]]
ev_low.describe()

#mailny 25 % of the people lead a helthy life with low Genetic risk has got a very low cancer level
# Out:
#               Age      Gender  Air Pollution  Alcohol use  \
# count  263.000000  263.000000     263.000000    263.00000
# mean    35.133080    1.547529       2.577947      2.00000
# std     12.671472    0.498685       0.924955      0.92876
# min     17.000000    1.000000       1.000000      1.00000
# 25%     25.000000    1.000000       2.000000      1.00000
# 50%     33.000000    2.000000       3.000000      2.00000
# 75%     42.500000    2.000000       3.000000      3.00000
# max     62.000000    2.000000       5.000000      4.00000
#
#        OccuPational Hazards  Genetic Risk  Balanced Diet     Obesity  \
# count            263.000000    263.000000     263.000000  263.000000
# mean               2.695817      2.311787       2.695817    2.395437
# std                1.029462      0.820616       1.101119    1.078723
# min                1.000000      1.000000       1.000000    1.000000
# 25%                2.000000      2.000000       2.000000    1.000000
# ...

# %%
df.loc[(df["Smoking"]>3) & (df["Alcohol use"] > 5) & (df["Air Pollution"] <= 5) & (df["OccuPational Hazards"] <= 5) & (df["Genetic Risk"] <= 5) & (df["Passive Smoker"] <= 5) & (df["Level"] == "Low"),["Patient Id","Age","Gender","Air Pollution","Alcohol use","OccuPational Hazards","Genetic Risk","Balanced Diet","Obesity","Smoking","Passive Smoker","Level"]]
# Out:
# Empty DataFrame
# Columns: [Patient Id, Age, Gender, Air Pollution, Alcohol use, OccuPational Hazards, Genetic Risk, Balanced Diet, Obesity, Smoking, Passive Smoker, Level]
# Index: []

# %% [raw]
# as a result we can say that the enviornement plays a major role in cancer the better enviornement and better lifestyle leads to a low
# level of cancer
# a interesting fact is these people tend to have less tendecny to alchohol and smoking
# but as we go to severe levels the patients living environement and habits becomes unhealthy which results us in a severe level of cancer
#
# as a result the enviornement, occupation hazards and etc will directly causes the unhelathy habitats which inturn leads to severe levels of cancer

# %%
ev_mid.loc[(ev_mid["Age"] >= 20) & (ev_mid["Age"] <= 50)]

#about majority of the people were middle aged 
#now lets look for the patients with healty diet and helthy living condition
# Out:
#     Patient Id  Age  Gender  Air Pollution  Alcohol use  OccuPational Hazards  \
# 9         P106   46       1              2            3                     2
# 26        P121   38       2              2            1                     3
# 29        P124   28       2              1            6                     5
# 63        P155   45       2              1            2                     4
# 65        P157   44       1              2            1                     3
# ..         ...  ...     ...            ...          ...                   ...
# 971       P973   36       2              2            1                     3
# 972       P974   31       2              3            2                     2
# 973       P975   38       2              1            2                     4
# 983       P984   26       1              3            2                     2
# 984       P985   37       1              1            2                     4
#
# ...

# %% [markdown]
# ### Symptoms and the level of Cancer

# %%
symptoms = ["Dust Allergy","chronic Lung Disease","Chest Pain","Coughing of Blood","Fatigue","Weight Loss","Shortness of Breath","Wheezing","Swallowing Difficulty","Clubbing of Finger Nails","Frequent Cold","Dry Cough","Level"]

# %%
sym = df.loc[(df["Dust Allergy"] > 5) & (df["chronic Lung Disease"]>5) & (df["Chest Pain"]>5) & (df["Coughing of Blood"]>5) & (df["Fatigue"]>5) & (df["Weight Loss"]>5) & (df["Shortness of Breath"]>5) & (df["Wheezing"]>5) & (df["Swallowing Difficulty"]>5) & (df["Clubbing of Finger Nails"]>5) & (df["Frequent Cold"]>5) & (df["Dry Cough"]>5), ["Dust Allergy","chronic Lung Disease","Chest Pain","Coughing of Blood","Fatigue","Weight Loss","Shortness of Breath","Wheezing","Swallowing Difficulty","Clubbing of Finger Nails","Frequent Cold","Dry Cough"]]
sym
# Out:
# Empty DataFrame
# Columns: [Dust Allergy, chronic Lung Disease, Chest Pain, Coughing of Blood, Fatigue, Weight Loss, Shortness of Breath, Wheezing, Swallowing Difficulty, Clubbing of Finger Nails, Frequent Cold, Dry Cough]
# Index: []

# %%
sym = temp.loc[:,["Dust Allergy","chronic Lung Disease","Chest Pain","Coughing of Blood","Fatigue","Weight Loss","Shortness of Breath","Wheezing","Swallowing Difficulty","Clubbing of Finger Nails","Frequent Cold","Dry Cough","Level"]]
sym.corr()

#from this we know that the facor like Dust Allergy,Chronic Lung Disease,chest pain,Coghing of blood *mainly*, and fatigue are highly related with the level of the cancer we have as a result consider these symptoms for the cancer
# Out:
#                           Dust Allergy  chronic Lung Disease  Chest Pain  \
# Dust Allergy                  1.000000              0.619556    0.639983
# chronic Lung Disease          0.619556              1.000000    0.782646
# Chest Pain                    0.639983              0.782646    1.000000
# Coughing of Blood             0.625291              0.602987    0.712158
# Fatigue                       0.332472              0.247697    0.251135
# Weight Loss                   0.321756              0.104080   -0.001092
# Shortness of Breath           0.518682              0.182426    0.237045
# Wheezing                      0.304850              0.057214    0.107211
# Swallowing Difficulty         0.031141              0.007279    0.071784
# Clubbing of Finger Nails      0.345714              0.298023    0.081386
# Frequent Cold                 0.219389              0.028759    0.042937
# Dry Cough                     0.300195              0.114161    0.142180
# ...

# %%
temp
# Out:
#     Patient Id  Age  Gender  Air Pollution  Alcohol use  Dust Allergy  \
# 0           P1   33       1              2            4             5
# 1          P10   17       1              3            1             5
# 2         P100   35       1              4            5             6
# 3        P1000   37       1              7            7             7
# 4         P101   46       1              6            8             7
# ..         ...  ...     ...            ...          ...           ...
# 995       P995   44       1              6            7             7
# 996       P996   37       2              6            8             7
# 997       P997   25       2              4            5             6
# 998       P998   18       2              6            8             7
# 999       P999   47       1              6            5             6
#
#      OccuPational Hazards  Genetic Risk  chronic Lung Disease  Balanced Diet  \
# ...

# %%
temp = df

# %%
temp
# Out:
#     Patient Id  Age  Gender  Air Pollution  Alcohol use  Dust Allergy  \
# 0           P1   33       1              2            4             5
# 1          P10   17       1              3            1             5
# 2         P100   35       1              4            5             6
# 3        P1000   37       1              7            7             7
# 4         P101   46       1              6            8             7
# ..         ...  ...     ...            ...          ...           ...
# 995       P995   44       1              6            7             7
# 996       P996   37       2              6            8             7
# 997       P997   25       2              4            5             6
# 998       P998   18       2              6            8             7
# 999       P999   47       1              6            5             6
#
#      OccuPational Hazards  Genetic Risk  chronic Lung Disease  Balanced Diet  \
# ...

# %%
df.loc[(df["Level"] == "Low") & (df["Balanced Diet"] > 7 ) & (df["Air Pollution"] < 4) & (df["OccuPational Hazards"] < 4)]

#as we can see the people with healthy background got no cancer according to our dataset
# Out:
# Empty DataFrame
# Columns: [Patient Id, Age, Gender, Air Pollution, Alcohol use, Dust Allergy, OccuPational Hazards, Genetic Risk, chronic Lung Disease, Balanced Diet, Obesity, Smoking, Passive Smoker, Chest Pain, Coughing of Blood, Fatigue, Weight Loss, Shortness of Breath, Wheezing, Swallowing Difficulty, Clubbing of Finger Nails, Frequent Cold, Dry Cough, Snoring, Level]
# Index: []
#
# [0 rows x 25 columns]

# %% [markdown]
# ## Conclusion

# %% [raw]
# Based on the analysis we classified the dataset into three with two type of patients and symptoms
#
# after analysing the first category of user considering their unhealthy habits are the reason for cancer , we found out the trend of
# unhealthy habits become dependant on the Enviornment they are living , such as their friends , office enviornement, Air polltion etc
# by focusing on these enviorenments we figured the users got cancer was even after they are from a healthy enviornement was due to their genes
# their own unhealthy habits
#
# and some of the people who got high level of cancer which was unlkely for them to have ,further checking their symproms found it was dues to
# their late treatement
#
# further more the majority of the patients who got high level cancer were middle aged people from a range if Age 20 to 50,
# and the old people with age above 50 got middle level caner
#
# while the young womans of age 18 got cancer of high level , which was caused due to their unhealthy enviornement
